# %% [markdown]
# ## Mappeoppgave 6

# %% [markdown]
# I samarbeid med Christian Karlsen

# %%
from bs4 import BeautifulSoup
import requests

def fetch_html_tables(url):
    "Returns a list of tables in the html of url"
    page = requests.get(url)
    bs=BeautifulSoup(page.content)
    tables=bs.find_all('table')
    return tables

tables=fetch_html_tables('https://no.wikipedia.org/wiki/Norges_fylker')
table_html=tables[1]


print(str(table_html)[:1000])
# Out:
# <table class="sortable wikitable">
# <tbody><tr>
# <th><a href="/wiki/Fylkesnummer" title="Fylkesnummer">Nummer</a><sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[a]</a></sup>
# </th>
# <th>Navn
# </th>
# <th>Fylkeskommunens hovedsete
# </th>
# <th>Statsforvalterens hovedsete
# </th>
# <th><a class="mw-redirect" href="/wiki/Valgdistrikt" title="Valgdistrikt">Valgdistrikt</a>
# </th>
# <th>Folketall<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[b]</a></sup><sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[5]</a></sup>
# </th>
# <th data-sort-type="number">Areal<sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[6]</a></sup>
# </th>
# <th>Ant. komm.
# </th>
# <th class="sortable wikitable">Målform<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[7]</a></sup>
# </th>
# <th><a class="mw-redirect" href="/wiki/Ordf%C3%B8rer_(Norge)" title="Ordfører (Norge)">Fylkesordfører</a>
# </th>
# <th><a href="/wiki/Statsforvalter" title="Statsforvalter">Statsforvalter</a>
# </th><

# %%
def html_to_table(html):
    "Returns the table defined in html as a list"
    table=[]
    for row in html.find_all('tr'):
        r=[]
        cells=row.find_all('td')

        if len(cells)==0:
            cells=row.find_all('th')
            

        for cell in cells:
            cell=format(cell)
            r.append(cell)
        

        table.append(r)
    return table

def format(cell):
    "Returns a string after converting bs4 object cell to clean text"
    if cell.content is None:
        s=cell.text
    elif len(cell.content)==0:
        return ''
    else:
        s=' '.join([str(c) for c in cell.content])
        
        
    s=s.replace('\xa0','')
    s=s.replace('\n','')
    s=s.replace(',','.')
    
    return s

table=html_to_table(table_html)


print(str(table)[:1000])
# Out:
# [['Nummer[a]', 'Navn', 'Fylkeskommunens hovedsete', 'Statsforvalterens hovedsete', 'Valgdistrikt', 'Folketall[b][5]', 'Areal[6]', 'Ant. komm.', 'Målform[7]', 'Fylkesordfører', 'Statsforvalter'], ['03', 'Oslo Oslo', 'Oslo', 'Moss[c]', 'Oslo', '693494', '454.12', '1', 'Nøytral', 'Marianne Borgen (SV)', 'Valgerd Svarstad Haugland'], ['11', 'Rogaland Rogaland', 'Stavanger', 'Stavanger', 'Rogaland', '479892', '9377.10', '23', 'Nøytral', 'Marianne Chesak (Ap)', 'Lone Merethe Solheim (konst.)'], ['15', 'Møre og Romsdal Møre og Romsdal', 'Molde', 'Molde', 'Møre og Romsdal', '265238', '14355.62', '26', 'Nynorsk', 'Jon Aasen (Ap)', 'Lodve Solholm'], ['18', 'Nordland Nordland (Nordlánnda)', 'Bodø', 'Bodø', 'Nordland', '241235', '38154.62', '41', 'Nøytral', 'Kari Anne Bøkestad Andreassen (Sp)', 'Tom Cato Karlsen'], ['30', 'Viken  Viken', 'Oslo. Drammen og Sarpsborg', 'Moss', 'AkershusBuskerudØstfold', '1241165', '24592.59', '51', 'Nøytral', 'Roger Ryberg (Ap)', 'Valgerd Svarstad Haugland'], ['34',

# %%
';'.join(table[0])
# Out:
# 'Nummer[a];Navn;Fylkeskommunens hovedsete;Statsforvalterens hovedsete;Valgdistrikt;Folketall[b][5];Areal[6];Ant. komm.;Målform[7];Fylkesordfører;Statsforvalter'

# %%
def save_data(file_name,table):
    "Saves table to file_name"
    f=open(file_name,'w')
    for row in table:
        f.write(';'.join(row)+'\n')
    f.close()
    
save_data('Fylka.csv',table)

# %%
import pandas as pd
Tabell=pd.read_csv('Fylka.csv', delimiter=';')
Tabell=Tabell.rename(columns={'Folketall[b][5]': 'Folketall'})
Tabell=Tabell.rename(columns={'Areal[6]': 'Areal'})
Tabell=Tabell.rename(columns={'Målform[7]': 'Målform'})
Tabell=Tabell.rename(columns={'Ant. komm.': 'Antall komunner'})
Tabell['Navn'] = Tabell['Navn'].replace(['Oslo Oslo'],'Oslo')
Tabell['Navn'] = Tabell['Navn'].replace(['Rogaland Rogaland'],'Rogaland')
Tabell['Navn'] = Tabell['Navn'].replace(['Møre og Romsdal Møre og Romsdal'],'Møre og Romsdal')
Tabell['Navn'] = Tabell['Navn'].replace(['Nordland Nordland (Nordlánnda)'],'Nordland')
Tabell['Navn'] = Tabell['Navn'].replace(['Viken  Viken'],'Viken')
Tabell['Navn'] = Tabell['Navn'].replace(['Innlandet Innlandet'],'Innlandet')
Tabell['Navn'] = Tabell['Navn'].replace(['Vestfold og Telemark Vestfold og Telemark'],'Vestfold og Telemark')
Tabell['Navn'] = Tabell['Navn'].replace(['Agder Agder'],'Agder')
Tabell['Navn'] = Tabell['Navn'].replace(['Vestland Vestland'],'Vestlandet')
Tabell['Navn'] = Tabell['Navn'].replace(['Trøndelag Trøndelag (Trööndelage)'],'Trøndelag')
Tabell['Navn'] = Tabell['Navn'].replace(['Troms Finnmark  Troms og Finnmark(Romsa ja Finnmárku)(Tromssa ja Finmarkku)'],'Troms og Finnmark')
Tabell
# Out:
#     Nummer[a]                  Navn  \
# 0           3                  Oslo
# 1          11              Rogaland
# 2          15       Møre og Romsdal
# 3          18              Nordland
# 4          30                 Viken
# 5          34             Innlandet
# 6          38  Vestfold og Telemark
# 7          42                 Agder
# 8          46            Vestlandet
# 9          50             Trøndelag
# 10         54     Troms og Finnmark
#
#                             Fylkeskommunens hovedsete  \
# 0                                                Oslo
# 1                                           Stavanger
# 2                                               Molde
# 3                                                Bodø
# 4                          Oslo. Drammen og Sarpsborg
# 5                                               Hamar
# 6                                               Skien
# 7                                        Kristiansand
# 8                                              Bergen
# 9   Steinkjer (fylkeskommunen)Trondheim (fylkesord...
# 10                                             Tromsø
#
#    Statsforvalterens hovedsete                 Valgdistrikt  Folketall  \
# 0                      Moss[c]                         Oslo     693494
# 1                    Stavanger                     Rogaland     479892
# 2                        Molde              Møre og Romsdal     265238
# 3                         Bodø                     Nordland     241235
# 4                         Moss      AkershusBuskerudØstfold    1241165
# 5                  Lillehammer               HedmarkOppland     371385
# 6                     Tønsberg             TelemarkVestfold     419396
# 7                      Arendal         Aust-AgderVest-Agder     307231
# 8                  Hermansverk    HordalandSogn og Fjordane     636531
# 9                    Steinkjer  Nord-TrøndelagSør-Trøndelag     468702
# 10                       Vadsø                FinnmarkTroms     243311
#
#        Areal  Antall komunner  Målform                      Fylkesordfører  \
# 0     454.12                1  Nøytral                Marianne Borgen (SV)
# 1    9377.10               23  Nøytral                Marianne Chesak (Ap)
# 2   14355.62               26  Nynorsk                      Jon Aasen (Ap)
# 3   38154.62               41  Nøytral  Kari Anne Bøkestad Andreassen (Sp)
# 4   24592.59               51  Nøytral                   Roger Ryberg (Ap)
# 5   52072.44               46  Nøytral          Even Aleksander Hagen (Ap)
# 6   17465.92               23  Nøytral            Terje Riis-Johansen (Sp)
# 7   16434.12               25  Nøytral                  Arne Thomassen (H)
# 8   33870.99               43  Nynorsk                   Jon Askeland (Sp)
# 9   42201.59               38  Nøytral                Tore O. Sandvik (Ap)
# 10  74829.68               39  Nøytral             Ivar B. Prestbakmo (Sp)
#
#                    Statsforvalter
# 0       Valgerd Svarstad Haugland
# 1   Lone Merethe Solheim (konst.)
# 2                   Lodve Solholm
# 3                Tom Cato Karlsen
# 4       Valgerd Svarstad Haugland
# 5                 Knut Storberget
# 6                  Per Arne Olsen
# 7              Stein A. Ytterdahl
# 8                   Lars Sponheim
# 9                   Frank Jenssen
# 10              Elisabeth Aspaker

# %%
Tabell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nummer[a]                    11 non-null     int64
#  1   Navn                         11 non-null     object
#  2   Fylkeskommunens hovedsete    11 non-null     object
#  3   Statsforvalterens hovedsete  11 non-null     object
#  4   Valgdistrikt                 11 non-null     object
#  5   Folketall                    11 non-null     int64
#  6   Areal                        11 non-null     float64
#  7   Antall komunner              11 non-null     int64
#  8   Målform                      11 non-null     object
#  9   Fylkesordfører               11 non-null     object
#  10  Statsforvalter               11 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.1+ KB

# %%
colors={'Oslo': '#E14827', 'Rogaland': '#84E127', 'Møre og Romsdal': '#2792E1', 'Nordland': '#BC27E1', 'Viken': '#E04A6C', 'Innlandet': '#00FFFF',
       'Vestfold og Telemark': '#0000CD', 'Agder': '#8B2323', 'Vestlandet': '#5F9EA0', 'Trøndelag': '#FF6103', 'Troms og Finnmark': '#DC143C'}


Tabell['colors']=Tabell['Navn'].apply(lambda x: colors[x.strip()])
Tabell
# Out:
#     Nummer[a]                  Navn  \
# 0           3                  Oslo
# 1          11              Rogaland
# 2          15       Møre og Romsdal
# 3          18              Nordland
# 4          30                 Viken
# 5          34             Innlandet
# 6          38  Vestfold og Telemark
# 7          42                 Agder
# 8          46            Vestlandet
# 9          50             Trøndelag
# 10         54     Troms og Finnmark
#
#                             Fylkeskommunens hovedsete  \
# 0                                                Oslo
# 1                                           Stavanger
# 2                                               Molde
# 3                                                Bodø
# 4                          Oslo. Drammen og Sarpsborg
# 5                                               Hamar
# 6                                               Skien
# 7                                        Kristiansand
# 8                                              Bergen
# 9   Steinkjer (fylkeskommunen)Trondheim (fylkesord...
# 10                                             Tromsø
#
#    Statsforvalterens hovedsete                 Valgdistrikt  Folketall  \
# 0                      Moss[c]                         Oslo     693494
# 1                    Stavanger                     Rogaland     479892
# 2                        Molde              Møre og Romsdal     265238
# 3                         Bodø                     Nordland     241235
# 4                         Moss      AkershusBuskerudØstfold    1241165
# 5                  Lillehammer               HedmarkOppland     371385
# 6                     Tønsberg             TelemarkVestfold     419396
# 7                      Arendal         Aust-AgderVest-Agder     307231
# 8                  Hermansverk    HordalandSogn og Fjordane     636531
# 9                    Steinkjer  Nord-TrøndelagSør-Trøndelag     468702
# 10                       Vadsø                FinnmarkTroms     243311
#
#        Areal  Antall komunner  Målform                      Fylkesordfører  \
# 0     454.12                1  Nøytral                Marianne Borgen (SV)
# 1    9377.10               23  Nøytral                Marianne Chesak (Ap)
# 2   14355.62               26  Nynorsk                      Jon Aasen (Ap)
# 3   38154.62               41  Nøytral  Kari Anne Bøkestad Andreassen (Sp)
# 4   24592.59               51  Nøytral                   Roger Ryberg (Ap)
# 5   52072.44               46  Nøytral          Even Aleksander Hagen (Ap)
# 6   17465.92               23  Nøytral            Terje Riis-Johansen (Sp)
# 7   16434.12               25  Nøytral                  Arne Thomassen (H)
# 8   33870.99               43  Nynorsk                   Jon Askeland (Sp)
# 9   42201.59               38  Nøytral                Tore O. Sandvik (Ap)
# 10  74829.68               39  Nøytral             Ivar B. Prestbakmo (Sp)
#
#                    Statsforvalter   colors
# 0       Valgerd Svarstad Haugland  #E14827
# 1   Lone Merethe Solheim (konst.)  #84E127
# 2                   Lodve Solholm  #2792E1
# 3                Tom Cato Karlsen  #BC27E1
# 4       Valgerd Svarstad Haugland  #E04A6C
# 5                 Knut Storberget  #00FFFF
# 6                  Per Arne Olsen  #0000CD
# 7              Stein A. Ytterdahl  #8B2323
# 8                   Lars Sponheim  #5F9EA0
# 9                   Frank Jenssen  #FF6103
# 10              Elisabeth Aspaker  #DC143C

# %%
from bokeh.plotting import figure

p = figure(
        title = "Verdier og inntekter top 20 klubber i verden", 
        x_axis_label = 'Inntekter',
        y_axis_label = 'Verdi',
        
    
    
        tools="hover", 
        tooltips = [
            ("Klubb","@Team"),
            ("Land","@country"),
            ("Verdi i Millioner dollar","@Value in$ millions"),
            ("Inntekter i millioner dollar","@Revenue ($M)"),
            ("Gjeld som prosent av verdi","@Debt as% of value")
            ], 
    
        plot_height = 1000,
        plot_width = 1500)

# %%
from bokeh.plotting import figure


Figur = figure(
        title = "Folketall og Areal for fylker i Norge \nStørelse på bobblen etter antall komunner i fylket", 
        x_axis_label = 'Areal',
        y_axis_label = 'Forlketall',
    
    
        tools="hover", 
        tooltips = [
            ("Fylke","@Navn"),
            ("Folketall","@Folketall"),
            ("Areal","@Areal"),
            ("Statsforvalter","@ komunner"),
            ],
    
        plot_height = 580,
        plot_width = 1100)

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import output_file

Figur.scatter(
    source=Tabell,
    y= 'Folketall', 
    x= 'Areal',
    
    
    size='Antall komunner',
    color= 'colors',
    legend_field='Navn',
    alpha= 0.5
    )

output_notebook()
output_file("Fylker.html")
show(Figur)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5393">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9d06d366-7f4f-4db8-8938-1547350cdb0e" data-root-id="5353"></div>

# %%
Figur.yaxis.major_label_overrides = { 200000: '200k', 400000: '400k', 600000: '600k', 800000: '800k', 1000000: '1M', 1200000: '1,2M' }
Figur.xaxis.major_label_overrides = { 20000: '20 000km^2', 40000: '40 000km^2', 60000: '60 000km^2', 80000: '80 000km^2'}
Figur.legend.location = "top_left"


output_notebook()
output_file("Fylker.html")
show(Figur)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3748">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0b21ed4a-2441-447d-9b9a-2dd46280faa1" data-root-id="3493"></div>

# %% [markdown]
# Kilder:
#
# Koder hentet fra forelesning med Espen Sirnes.
# Koder hentet fra: https://datatofish.com/replace-values-pandas-dataframe/
# Farger hentet fra: https://www.webucator.com/article/python-color-constants-module/
# Tabell hentet fra: https://no.wikipedia.org/wiki/Norges_fylker
